# %%
import os
import sys

# Set the repo root
repo_root = r"C:\Users\gizem\Desktop\Humber College\Semester 2\Machine Learning AI Bioinforma\BINF-5507-Winter2026\BINF-5507-Winter2026\Assignment_1_GizemEsraGenc"
os.chdir(repo_root)
print("Current working directory:", os.getcwd())

# Add src folder to Python path so we can import preprocess.py
sys.path.append(os.path.join(repo_root, "src"))

# Now import your functions
from preprocess import detect_feature_types, encode_categorical, scale_numeric
# Out:
# Current working directory: C:\Users\gizem\Desktop\Humber College\Semester 2\Machine Learning AI Bioinforma\BINF-5507-Winter2026\BINF-5507-Winter2026\Assignment_1_GizemEsraGenc
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 13
#      10 sys.path.append(os.path.join(repo_root, "src"))
#      12 # Now import your functions
# ---> 13 from preprocess import detect_feature_types, encode_categorical, scale_numeric
#
# ImportError: cannot import name 'detect_feature_types' from 'preprocess' (C:\Users\gizem\Desktop\Humber College\Semester 2\Machine Learning AI Bioinforma\BINF-5507-Winter2026\BINF-5507-Winter2026\Assignment_1_GizemEsraGenc\src\preprocess.py)

# %%
import pandas as pd

# Load your heart disease dataset
df = pd.read_csv("heart_disease_dataset.csv")

# 1️⃣ Detect feature types
cat_cols, num_cols = detect_feature_types(df)
print("Categorical columns:", cat_cols)
print("Numeric columns:", num_cols)

# 2️⃣ Encode categorical features
df_encoded, new_cols = encode_categorical(df, cat_cols)
print("New one-hot encoded columns added:", new_cols)

# 3️⃣ Scale numeric features
df_scaled = scale_numeric(df_encoded, num_cols)
print("Preview of scaled dataframe:")
print(df_scaled.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       4 df = pd.read_csv("heart_disease_dataset.csv")
#       6 # 1️⃣ Detect feature types
# ----> 7 cat_cols, num_cols = detect_feature_types(df)
#       8 print("Categorical columns:", cat_cols)
#       9 print("Numeric columns:", num_cols)
#
# NameError: name 'detect_feature_types' is not defined
